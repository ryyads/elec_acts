# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 warnings.filterwarnings('ignore')
#       5 housing=pd.read_csv('datasets\\housing_train.csv')
# ----> 6 y=housing('SalePrice')
#
# TypeError: 'DataFrame' object is not callable
